# %% [markdown]
# <h1>Instagram Reach analysis</h1>
#
# <h3>In this notebook we will try to predict the reach of an instagram post.</h3>
#
# Data consists for following features:
# 1. Impressions: Number of impressions in a post (Reach)
# 2. From Home: Reach from home
# 3. From Hashtags: Reach from Hashtags
# 4. From Explore: Reach from Explore
# 5. From Other: Reach from other sources
# 6. Saves: Number of saves
# 7. Comments: Number of comments
# 8. Shares: Number of shares
# 9. Likes: Number of Likes
# 10. Profile Visits: Numer of profile visits from the post
# 11. Follows: Number of Follows from the post
# 12. Caption: Caption of the post
# 13. Hashtags: Hashtags used in the post

# %%
# Library imports
import pandas as pd

# %% [markdown]
# <h2>Import Data</h2>

# %%
df = pd.read_csv('data.csv', encoding='latin1')
df.head()
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# 1         7      14    224              48       10
# 2        11       1    131              62       12
# 3        10       7    213              23        8
# 4         5       4    123               8        0
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# ...

# %% [markdown]
# <h2>Data Cleaning</h2>

# %%
# Checking for any null values
df.isnull().sum()
# Out:
# Impressions       0
# From Home         0
# From Hashtags     0
# From Explore      0
# From Other        0
# Saves             0
# Comments          0
# Shares            0
# Likes             0
# Profile Visits    0
# Follows           0
# Caption           0
# Hashtags          0
# dtype: int64

# %%
# Checking for any NA values
df.isna().sum()
# df.dropna()
# Out:
# Impressions       0
# From Home         0
# From Hashtags     0
# From Explore      0
# From Other        0
# Saves             0
# Comments          0
# Shares            0
# Likes             0
# Profile Visits    0
# Follows           0
# Caption           0
# Hashtags          0
# dtype: int64

# %% [markdown]
# <h5>Here there is no 'null' or 'NA' value so, data is clean</h5>

# %% [markdown]
# <h2>Data Exploration / Analysis</h2>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df.describe()
# Out:
#         Impressions     From Home  From Hashtags  From Explore   From Other  \
# count    119.000000    119.000000     119.000000    119.000000   119.000000
# mean    5703.991597   2475.789916    1887.512605   1078.100840   171.092437
# std     4843.780105   1489.386348    1884.361443   2613.026132   289.431031
# min     1941.000000   1133.000000     116.000000      0.000000     9.000000
# 25%     3467.000000   1945.000000     726.000000    157.500000    38.000000
# 50%     4289.000000   2207.000000    1278.000000    326.000000    74.000000
# 75%     6138.000000   2602.500000    2363.500000    689.500000   196.000000
# max    36919.000000  13473.000000   11817.000000  17414.000000  2547.000000
#
#              Saves    Comments      Shares       Likes  Profile Visits  \
# count   119.000000  119.000000  119.000000  119.000000      119.000000
# mean    153.310924    6.663866    9.361345  173.781513       50.621849
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Impressions     119 non-null    int64
#  1   From Home       119 non-null    int64
#  2   From Hashtags   119 non-null    int64
#  3   From Explore    119 non-null    int64
#  4   From Other      119 non-null    int64
#  5   Saves           119 non-null    int64
#  6   Comments        119 non-null    int64
#  7   Shares          119 non-null    int64
#  8   Likes           119 non-null    int64
#  9   Profile Visits  119 non-null    int64
#  10  Follows         119 non-null    int64
#  11  Caption         119 non-null    object
#  12  Hashtags        119 non-null    object
# dtypes: int64(11), object(2)
# memory usage: 12.2+ KB

# %% [markdown]
# <h3>Distribution of Impressions From Home</h3>

# %%
sns.displot(df['From Home'], kde=True, height=7, aspect=2)

# %% [markdown]
# <h4>Conclusion:</h4>

# %% [markdown]
# <h3>Distribution of Impressions From Hashtags</h3>

# %%
sns.displot(df['From Hashtags'], kde=True, height=7, aspect=2)

# %% [markdown]
# <h4>Conclusion:</h4>

# %% [markdown]
# <h3>Distribution of Impressions From Explore</h3>

# %%
sns.displot(df['From Explore'], kde=True, height=7, aspect=2)

# %% [markdown]
# <h4>Conclusion:</h4>

# %% [markdown]
# <h3>Percentage of impressions from various sources</h3>

# %%
home = df["From Home"].sum()
hashtags = df['From Hashtags'].sum()
explore = df['From Explore'].sum()
other = df['From Other'].sum()

labels = ['From Home', 'From Hashtags', 'From Explore', 'From Other']
values = [home, hashtags, explore, other]

plt.pie(x=values, labels=labels, autopct='%1.0f%%')
plt.show()
#px.pie(df, values=values, labels=labels, title='Impressions from various sources')

# %% [markdown]
# <h4>Conclusion: 44% of the reach is from the followers (From Home), 34% is from hashtags, so here hashtags also plays a very imp role, 19% from explore which is by promoting and 3% from other</h4>

# %% [markdown]
# <h2>Analysing relationships</h2>
#
# To find the most important factorsof our instagram reach which will also help us to understand how instagram algo works

# %% [markdown]
# <h3> Relation between Likes and Reach</h3>

# %%
sns.regplot(data=df, y='Likes', x='Impressions')
# Out:
# <AxesSubplot: xlabel='Impressions', ylabel='Likes'>

# %% [markdown]
# <h4>This plot shows there is a linear relationship between No. of likes and Impressions</h4>

# %% [markdown]
# <h3> Relation between Comments and Reach</h3>

# %%
sns.regplot(data=df, y='Comments', x='Impressions')
# Out:
# <AxesSubplot: xlabel='Impressions', ylabel='Comments'>

# %% [markdown]
# <h4>This plot shows there is no much effect of Comments on Impressions</h4>

# %% [markdown]
# <h3> Relation between Shares and Reach</h3>

# %%
sns.regplot(data=df, y='Shares', x='Impressions')
# Out:
# <AxesSubplot: xlabel='Impressions', ylabel='Shares'>

# %% [markdown]
# <h4>This plot shows that more no. of share increases the impressions but not as much as of likes</h4>

# %% [markdown]
# <h3> Relation between Saves and Reach</h3>

# %%
sns.regplot(data=df, y='Saves', x='Impressions')
# Out:
# <AxesSubplot: xlabel='Impressions', ylabel='Saves'>

# %% [markdown]
# <h4>This plot shows there is a linear relationship between Saves and Reach</h4>

# %% [markdown]
# <h2>Correlation</h2>

# %%
df.corr()['Impressions'].sort_values(ascending=False)
# Out:
# /var/folders/v8/s752sg95209c7mrl_31hp1k80000gp/T/ipykernel_85626/780055283.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Impressions'].sort_values(ascending=False)
# Impressions       1.000000
# From Explore      0.893607
# Follows           0.889363
# Likes             0.849835
# From Home         0.844698
# Saves             0.779231
# Profile Visits    0.760981
# Shares            0.634675
# From Other        0.592960
# From Hashtags     0.560760
# Comments         -0.028524
# Name: Impressions, dtype: float64

# %% [markdown]
# <h2>Analysing conversion rate</h2>
#
# This means how many followers you get from profile visits. It can be calculated by (Follow/Profile_Visit) * 100

# %%
(df['Follows'].sum() / df['Profile Visits'].sum()) * 100
# Out:
# 41.00265604249668

# %% [markdown]
# #### This is a very good conversion rate
#
# Lets look at total profile visits and the no. of followers gained

# %%
sns.regplot(data=df, x='Profile Visits', y='Follows')
# Out:
# <AxesSubplot: xlabel='Profile Visits', ylabel='Follows'>

# %% [markdown]
# <h4>So, we can say that as no. of profile visits increases, followers increases</h4>

# %% [markdown]
# <h2>Prediction model</h2>

# %% [markdown]
# <h4>Splitting the data into train and test</h4>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import PassiveAggressiveRegressor, LinearRegression
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

# %%
X = np.array(df[['Follows', 'Likes', 'Saves', 'Profile Visits', 'Shares', 'Comments']])
Y = np.array(df['Impressions'])
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = PassiveAggressiveRegressor()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.7559192703777224

# %%
# Features = [['Likes','Saves', 'Comments', 'Shares', 'Profile Visits', 'Follows']]
features = np.array([[282.0, 233.0, 4.0, 9.0, 165.0, 54.0]])
model.predict(features)
# Out:
# array([14703.65670381])

# %%
Yhat = model.predict(X_test)
print("Mean absolute error: ", mean_absolute_error(y_test, Yhat))
print("Mean squared error: ", mean_squared_error(y_test, Yhat))
print("R2 error: ", r2_score(y_test, Yhat))
# Out:
# Mean absolute error:  1720.7565783257871
# Mean squared error:  4491845.301981668
# R2 error:  0.8843433128497666

# %%
sns.kdeplot(y_test, color='r', fill=True)
sns.kdeplot(Yhat, color='b', fill=True)
# Out:
# <AxesSubplot: ylabel='Density'>

# %% [markdown]
# <h2>References</h2>

# %% [markdown]
# <h3>Article referred: <a href="https://thecleverprogrammer.com/2022/03/22/instagram-reach-analysis-using-python/">Instagram Reach Analysis using Python</a> by <a href="https://thecleverprogrammer.com/author/amankharwal/">Aman Kharwal</a></h3>
